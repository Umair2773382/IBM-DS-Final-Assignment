# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# Final_DS_Assignment.ipynb

# %% [markdown]
# Introduction
# This notebook demonstrates basic data science concepts and exercises using Markdown and Python code cells.

# %% [markdown]
# Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Java

# %% [markdown]
# Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# Data Science Tools
#
# | Tool Name        | Purpose                          |
# |------------------|----------------------------------|
# | Jupyter Notebook | Interactive coding and analysis  |
# | RStudio          | Statistical analysis and plots   |
# | Apache Spark     | Big data processing              |
# | Git/GitHub       | Version control                  |
# | Tableau          | Data visualization               |

# %% [markdown]
# Arithmetic Expression Examples
# The following code cells will demonstrate basic arithmetic operations in Python.

# %%
# Multiply and add numbers
a = 5
b = 10
c = 3

result = a * b + c
result
# Out:
# 53

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours
# Out:
# 2.0

# %% [markdown]
# Objectives
# 1. Learn to use Markdown in Jupyter Notebooks
# 2. Practice basic Python arithmetic operations
# 3. Understand how to organize a notebook for a final assignment
# 4. Gain experience in creating tables and lists in Markdown

# %% [markdown]
# Author
# Syed Umair Ali Shah
